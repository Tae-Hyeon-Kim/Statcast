# %%
import pandas as pd
import pybaseball
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import shapiro
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.stats import weightstats
import plotly.express as px
from sklearn.preprocessing import StandardScaler
import pybaseball
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
from statsmodels.stats.multicomp import pairwise_tukeyhsd, MultiComparison
from statsmodels.stats.multitest import multipletests
import pickle
import gzip

# %%
with gzip.open('statcast_data.pkl','rb') as f:
    df1 = pickle.load(f)

# %%
# count 추가
with gzip.open('statcast_data_groupby_ver2.pkl','rb') as f:
    df2 = pickle.load(f)

# %%
# with gzip.open('statcast_data_groupby.pkl','rb') as f:
#     df3 = pickle.load(f)

# %%
df1_gp = df1.groupby(['Season','player_name','pitcher','pitch_type'])[['release_speed','pfx_x','pfx_z','vx0','vy0','vz0','ax','ay','az','effective_speed','release_spin_rate','release_extension']].mean().reset_index()
df1_gp
# Out:
#      Season      player_name  pitcher pitch_type  release_speed     pfx_x  \
# 0      2020    Abreu, Albert   656061         CH      86.680000 -1.509000
# 1      2020    Abreu, Albert   656061         CU      81.666667  0.593333
# 2      2020    Abreu, Albert   656061         FF      96.363636 -1.060000
# 3      2020    Abreu, Albert   656061         SL      85.750000  0.328750
# 4      2020     Abreu, Bryan   650556         CH      91.600000 -0.440000
# ...     ...              ...      ...        ...            ...       ...
# 5202   2024  Yarbrough, Ryan   642232         CH      77.444954  1.334587
# 5203   2024  Yarbrough, Ryan   642232         CU      71.503782 -1.297143
# 5204   2024  Yarbrough, Ryan   642232         FC      83.625517  0.099724
# 5205   2024  Yarbrough, Ryan   642232         FF      86.247500  1.175375
# 5206   2024  Yarbrough, Ryan   642232         SI      85.672589  1.378934
#
#          pfx_z        vx0         vy0       vz0         ax         ay  \
# ...

# %%
tmp_stat3 = df1.groupby(['Season','player_name','pitcher','pitch_type']).size().reset_index().rename(columns={0:'count'})
df1_gp_cnt = pd.merge(df1_gp,tmp_stat3,on=['Season','player_name','pitcher','pitch_type'])
df1_gp_cnt
# Out:
#      Season      player_name  pitcher pitch_type  release_speed     pfx_x  \
# 0      2020    Abreu, Albert   656061         CH      86.680000 -1.509000
# 1      2020    Abreu, Albert   656061         CU      81.666667  0.593333
# 2      2020    Abreu, Albert   656061         FF      96.363636 -1.060000
# 3      2020    Abreu, Albert   656061         SL      85.750000  0.328750
# 4      2020     Abreu, Bryan   650556         CH      91.600000 -0.440000
# ...     ...              ...      ...        ...            ...       ...
# 5202   2024  Yarbrough, Ryan   642232         CH      77.444954  1.334587
# 5203   2024  Yarbrough, Ryan   642232         CU      71.503782 -1.297143
# 5204   2024  Yarbrough, Ryan   642232         FC      83.625517  0.099724
# 5205   2024  Yarbrough, Ryan   642232         FF      86.247500  1.175375
# 5206   2024  Yarbrough, Ryan   642232         SI      85.672589  1.378934
#
#          pfx_z        vx0         vy0       vz0         ax         ay  \
# ...

# %%
with gzip.open('statcast_data_groupby_ver3_0725.pkl', 'wb') as f:
    pickle.dump(df1_gp_cnt, f)
